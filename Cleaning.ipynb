# %% [markdown]
# # DATA CLEANING- HR ATTRITION ANALYTICS

# %%
import pandas as pd
import pyodbc

# Define connection parameters
server = 'LAPTOP-BBVTJVFN\SQLEXPRESS'              # or your server name, e.g., 'DESKTOP-XYZ\SQLEXPRESS'
database = 'HrAnalytics'
table = 'HR_Attrition_Unclean'

# Connection string using Windows Authentication
conn_str = (
    'Driver={SQL Server};'
    f'Server={server};'
    f'Database={database};'
    'Trusted_Connection=yes;'
)

# Create connection
conn = pyodbc.connect(conn_str)

# Read data into a DataFrame
query = f"SELECT * FROM {table}"
df = pd.read_sql(query, conn)

# Close connection
conn.close()

# Preview data
print(df.head())
# Out:
#   EmployeeID     Age       Department Education                JobRole  \
# 0     2632.0    None              R&D         3             Executive
# 1     1621.0      31  Human Resources         3  Laboratory Technician
# 2     5665.0      38              rnd       Two                Manager
# 3       None    None             None         4              Scientist
# 4     2035.0  Thirty            Sales       Two                   Tech
#
#    Gender MonthlyIncome  DateOfJoining OverTime BusinessTravel  ...  \
# 0    None          8699  Not Available       No     Non-Travel  ...
# 1    male         12125           None      yes  Travel_Rarely  ...
# 2  Female          None     12-05-2018        Y           None  ...
# 3    male          9831     2019-07-28      Yes         Rarely  ...
# 4    Male          None  Not Available       No     Non-Travel  ...
#
#   JobSatisfaction WorkLifeBalance EnvironmentSatisfaction  \
# 0               2               1                       3
# 1               4               2                       3
# 2               3               3                       2
# 3             Low               2                    None
# 4            None            Poor                       4
#
#   YearsSinceLastPromotion YearsWithCurrManager JobInvolvement Attrition  \
# 0                    None                    4              3       Yes
# 1                    None                 None              4       yes
# 2                    None                    4              4      None
# 3                       4                    8              4       Yes
# 4                    None                 None              4      None
#
#   StockOptionLevel PercentSalaryHike TotalWorkingYears
# 0             Zero                19                \r
# 1                2              None               5\r
# 2                0              None              13\r
# 3                1              None          Twenty\r
# 4             Zero                15          Twenty\r
#
# [5 rows x 25 columns]
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_19544\351142916.py:5: SyntaxWarning: invalid escape sequence '\S'
#   server = 'LAPTOP-BBVTJVFN\SQLEXPRESS'              # or your server name, e.g., 'DESKTOP-XYZ\SQLEXPRESS'
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_19544\351142916.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
# Display basic info and first few rows to understand the structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               965 non-null    object
#  1   Age                      660 non-null    object
#  2   Department               873 non-null    object
#  3   Education                846 non-null    object
#  4   JobRole                  891 non-null    object
#  5   Gender                   838 non-null    object
#  6   MonthlyIncome            682 non-null    object
#  7   DateOfJoining            733 non-null    object
#  8   OverTime                 826 non-null    object
#  9   BusinessTravel           835 non-null    object
#  10  MaritalStatus            857 non-null    object
#  11  YearsAtCompany           644 non-null    object
#  12  DistanceFromHome         753 non-null    object
#  13  PerformanceRating        840 non-null    object
#  14  TrainingTimesLastYear    674 non-null    object
#  15  JobSatisfaction          839 non-null    object
#  16  WorkLifeBalance          829 non-null    object
#  17  EnvironmentSatisfaction  864 non-null    object
#  18  YearsSinceLastPromotion  672 non-null    object
#  19  YearsWithCurrManager     649 non-null    object
#  20  JobInvolvement           845 non-null    object
#  21  Attrition                842 non-null    object
#  22  StockOptionLevel         837 non-null    object
#  23  PercentSalaryHike        651 non-null    object
#  24  TotalWorkingYears        1000 non-null   object
# dtypes: object(25)
# memory usage: 195.4+ KB

# %%
df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Feature 1: EmployeeID (Handling Missing & Invalid IDs)

# %%
def clean_employee_id(df):
    # Remove rows with missing EmployeeID
    df = df[df['EmployeeID'].notnull()]
    # Convert to integer
    df['EmployeeID'] = df['EmployeeID'].astype(object)
    return df
clean_employee_id(df)
# df["EmployeeID"] = df["EmployeeID"].apply(lambda x : "Emp_" + str(x))
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_19544\521510802.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EmployeeID'] = df['EmployeeID'].astype(object)
#     EmployeeID     Age       Department Education                JobRole  \
# 0       2632.0    None              R&D         3             Executive
# 1       1621.0      31  Human Resources         3  Laboratory Technician
# 2       5665.0      38              rnd       Two                Manager
# 4       2035.0  Thirty            Sales       Two                   Tech
# 5       3248.0      21  Human Resources         4                   None
# ..         ...     ...              ...       ...                    ...
# 994     9441.0      52             None         4              Executive
# 995     8129.0      41              rnd         1     Research Scientist
# 996     6899.0      23            Sales      None              Executive
# 998     1155.0    None              R&D         3     Research Scientist
# 999     3233.0  Thirty              rnd       Two                   None
#
#      Gender MonthlyIncome  DateOfJoining OverTime BusinessTravel  ...  \
# 0      None          8699  Not Available       No     Non-Travel  ...
# 1      male         12125           None      yes  Travel_Rarely  ...
# 2    Female          None     12-05-2018        Y           None  ...
# 4      Male          None  Not Available       No     Non-Travel  ...
# 5      male          6776     2016-01-23        N           None  ...
# ..      ...           ...            ...      ...            ...  ...
# 994       F         14587  Not Available     None     Frequently  ...
# 995    Male         19004     12-05-2018        N  Travel_Rarely  ...
# 996       M          7532     12-05-2018      Yes         Rarely  ...
# 998    Male         10829           None        N           None  ...
# 999       F         19252           None       No     Non-Travel  ...
#
#     JobSatisfaction WorkLifeBalance EnvironmentSatisfaction  \
# 0                 2               1                       3
# 1                 4               2                       3
# 2                 3               3                       2
# 4              None            Poor                       4
# 5               Low               2                    Good
# ..              ...             ...                     ...
# 994             Low               4                    None
# 995               3               4                       2
# 996               1            None                       4
# 998               3               2                    Good
# 999               3               1                       1
#
#     YearsSinceLastPromotion YearsWithCurrManager JobInvolvement Attrition  \
# 0                      None                    4              3       Yes
# 1                      None                 None              4       yes
# 2                      None                    4              4      None
# 4                      None                 None              4      None
# 5                         8                 Five              1         Y
# ..                      ...                  ...            ...       ...
# 994                       4                 None              4       yes
# 995                       0                 None           None         Y
# 996                    None                 None              4        No
# 998                    None                    0           High       Yes
# 999                       8                   14              1       Yes
#
#     StockOptionLevel PercentSalaryHike TotalWorkingYears
# 0               Zero                19                \r
# 1                  2              None               5\r
# 2                  0              None              13\r
# 4               Zero                15          Twenty\r
# 5                  0                24               1\r
# ..               ...               ...               ...
# 994                2              None                \r
# 995                2                23          Twenty\r
# 996             None                21          Twenty\r
# 998                3                11          Twenty\r
# 999                3                11                \r
#
# [965 rows x 25 columns]

# %% [markdown]
# # Feature 2: Age (Handling Non-Numeric, Missing, and Invalid Entries)

# %%
df["Age"].unique()
# Out:
# array([None, '31', '38', 'Thirty', '21', '29', '49', '23', '26', '25',
#        '55', '50', '43', '27', '40', '32', '54', '33', '41', '51', '47',
#        '45', '48', '37', '59', '44', '20', '46', '56', '42', '58', '28',
#        '53', '36', '39', '24', '22', '35', '57', '60', '30', '52', '34'],
#       dtype=object)

# %%
def clean_age(Data):
    def convert_age(x):
        try:
            return int(x)
        except:
            if isinstance(x,str) and x.lower() == "thirty":
                return 13
            return None
    Data["Age"] = Data["Age"].apply(convert_age)

    # handling null values
    Data["Age"] = Data["Age"].fillna(Data["Age"].median())
    return df

clean_age(df)
# Out:
#     EmployeeID   Age       Department Education                JobRole  \
# 0       2632.0  13.0              R&D         3             Executive
# 1       1621.0  31.0  Human Resources         3  Laboratory Technician
# 2       5665.0  38.0              rnd       Two                Manager
# 3         None  13.0             None         4              Scientist
# 4       2035.0  13.0            Sales       Two                   Tech
# ..         ...   ...              ...       ...                    ...
# 995     8129.0  41.0              rnd         1     Research Scientist
# 996     6899.0  23.0            Sales      None              Executive
# 997       None  13.0             None       Two              Executive
# 998     1155.0  13.0              R&D         3     Research Scientist
# 999     3233.0  13.0              rnd       Two                   None
#
#      Gender MonthlyIncome  DateOfJoining OverTime BusinessTravel  ...  \
# 0      None          8699  Not Available       No     Non-Travel  ...
# 1      male         12125           None      yes  Travel_Rarely  ...
# 2    Female          None     12-05-2018        Y           None  ...
# 3      male          9831     2019-07-28      Yes         Rarely  ...
# 4      Male          None  Not Available       No     Non-Travel  ...
# ..      ...           ...            ...      ...            ...  ...
# 995    Male         19004     12-05-2018        N  Travel_Rarely  ...
# 996       M          7532     12-05-2018      Yes         Rarely  ...
# 997  Female         13545  Not Available      Yes         Rarely  ...
# 998    Male         10829           None        N           None  ...
# 999       F         19252           None       No     Non-Travel  ...
#
#     JobSatisfaction WorkLifeBalance EnvironmentSatisfaction  \
# 0                 2               1                       3
# 1                 4               2                       3
# 2                 3               3                       2
# 3               Low               2                    None
# 4              None            Poor                       4
# ..              ...             ...                     ...
# 995               3               4                       2
# 996               1            None                       4
# 997               1            None                       4
# 998               3               2                    Good
# 999               3               1                       1
#
#     YearsSinceLastPromotion YearsWithCurrManager JobInvolvement Attrition  \
# 0                      None                    4              3       Yes
# 1                      None                 None              4       yes
# 2                      None                    4              4      None
# 3                         4                    8              4       Yes
# 4                      None                 None              4      None
# ..                      ...                  ...            ...       ...
# 995                       0                 None           None         Y
# 996                    None                 None              4        No
# 997                    None                 None              1       Yes
# 998                    None                    0           High       Yes
# 999                       8                   14              1       Yes
#
#     StockOptionLevel PercentSalaryHike TotalWorkingYears
# 0               Zero                19                \r
# 1                  2              None               5\r
# 2                  0              None              13\r
# 3                  1              None          Twenty\r
# 4               Zero                15          Twenty\r
# ..               ...               ...               ...
# 995                2                23          Twenty\r
# 996             None                21          Twenty\r
# 997                3              None                \r
# 998                3                11          Twenty\r
# 999                3                11                \r
#
# [1000 rows x 25 columns]

# %%
df["Age"].unique()
# Out:
# array([13., 31., 38., 21., 29., 49., 23., 26., 25., 55., 50., 43., 27.,
#        40., 32., 54., 33., 41., 51., 47., 45., 48., 37., 59., 44., 20.,
#        46., 56., 42., 58., 28., 53., 36., 39., 24., 22., 35., 57., 60.,
#        30., 52., 34.])

# %% [markdown]
# # Feature 3: Department
# Issues Identified:
#
# Missing values
#
# Incorrect values like 'rnd' instead of 'R&D'

# %%
df["Department"].unique()
# Out:
# array(['R&D', 'Human Resources', 'rnd', None, 'Sales', 'HR',
#        'Research & Development'], dtype=object)

# %%
def clean_department(Data):

    Data["Department"] = Data["Department"].str.strip().str.title()

    # Manual correction
    Data["Department"] = Data["Department"].str.lower()
    Data["Department"] = Data["Department"].replace({"r&d":"Research & Development","rnd":"Research & Development","hr":"Human Resources","research & development":"Research & Development","human resources":"Human Resources","sales":"Sales"})
    Data["Department"] = Data["Department"].fillna("Unknown")
    return df
clean_department(df)
# Out:
#     EmployeeID   Age              Department Education                JobRole  \
# 0       2632.0  13.0  Research & Development         3             Executive
# 1       1621.0  31.0         Human Resources         3  Laboratory Technician
# 2       5665.0  38.0  Research & Development       Two                Manager
# 3         None  13.0                 Unknown         4              Scientist
# 4       2035.0  13.0                   Sales       Two                   Tech
# ..         ...   ...                     ...       ...                    ...
# 995     8129.0  41.0  Research & Development         1     Research Scientist
# 996     6899.0  23.0                   Sales      None              Executive
# 997       None  13.0                 Unknown       Two              Executive
# 998     1155.0  13.0  Research & Development         3     Research Scientist
# 999     3233.0  13.0  Research & Development       Two                   None
#
#      Gender MonthlyIncome  DateOfJoining OverTime BusinessTravel  ...  \
# 0      None          8699  Not Available       No     Non-Travel  ...
# 1      male         12125           None      yes  Travel_Rarely  ...
# 2    Female          None     12-05-2018        Y           None  ...
# 3      male          9831     2019-07-28      Yes         Rarely  ...
# 4      Male          None  Not Available       No     Non-Travel  ...
# ..      ...           ...            ...      ...            ...  ...
# 995    Male         19004     12-05-2018        N  Travel_Rarely  ...
# 996       M          7532     12-05-2018      Yes         Rarely  ...
# 997  Female         13545  Not Available      Yes         Rarely  ...
# 998    Male         10829           None        N           None  ...
# 999       F         19252           None       No     Non-Travel  ...
#
#     JobSatisfaction WorkLifeBalance EnvironmentSatisfaction  \
# 0                 2               1                       3
# 1                 4               2                       3
# 2                 3               3                       2
# 3               Low               2                    None
# 4              None            Poor                       4
# ..              ...             ...                     ...
# 995               3               4                       2
# 996               1            None                       4
# 997               1            None                       4
# 998               3               2                    Good
# 999               3               1                       1
#
#     YearsSinceLastPromotion YearsWithCurrManager JobInvolvement Attrition  \
# 0                      None                    4              3       Yes
# 1                      None                 None              4       yes
# 2                      None                    4              4      None
# 3                         4                    8              4       Yes
# 4                      None                 None              4      None
# ..                      ...                  ...            ...       ...
# 995                       0                 None           None         Y
# 996                    None                 None              4        No
# 997                    None                 None              1       Yes
# 998                    None                    0           High       Yes
# 999                       8                   14              1       Yes
#
#     StockOptionLevel PercentSalaryHike TotalWorkingYears
# 0               Zero                19                \r
# 1                  2              None               5\r
# 2                  0              None              13\r
# 3                  1              None          Twenty\r
# 4               Zero                15          Twenty\r
# ..               ...               ...               ...
# 995                2                23          Twenty\r
# 996             None                21          Twenty\r
# 997                3              None                \r
# 998                3                11          Twenty\r
# 999                3                11                \r
#
# [1000 rows x 25 columns]

# %%
df["Department"].unique()
# Out:
# array(['Research & Development', 'Human Resources', 'Unknown', 'Sales'],
#       dtype=object)

# %% [markdown]
# # Feature 4: Education
# Issues Identified:
#
# Numeric categorical, needs description mapping

# %%
df["Education"].unique()
# Out:
# array(['3', 'Two', '4', '2', '5', '1', None], dtype=object)

# %%
def clean_education(df):
    education_map = {
        1: 'Below College',
        2: 'College',
        3: 'Bachelor',
        4: 'Master',
        5: 'Doctor'
    }
    df["Education"] = df["Education"].replace("Two","2")
    df["Education"] = pd.to_numeric(df["Education"],errors="coerce")
    df["Education"] = df["Education"].map(education_map)
    df["Education"] = df["Education"].fillna("Other")
    return df

    
clean_education(df)
# Out:
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender MonthlyIncome  DateOfJoining OverTime  \
# 0               Executive     None          8699  Not Available       No
# 1    Laboratory Technician    male         12125           None      yes
# 2                  Manager  Female          None     12-05-2018        Y
# 3                Scientist    male          9831     2019-07-28      Yes
# 4                     Tech    Male          None  Not Available       No
# ..                     ...     ...           ...            ...      ...
# 995     Research Scientist    Male         19004     12-05-2018        N
# 996              Executive       M          7532     12-05-2018      Yes
# 997              Executive  Female         13545  Not Available      Yes
# 998     Research Scientist    Male         10829           None        N
# 999                   None       F         19252           None       No
#
#     BusinessTravel  ... JobSatisfaction WorkLifeBalance  \
# 0       Non-Travel  ...               2               1
# 1    Travel_Rarely  ...               4               2
# 2             None  ...               3               3
# 3           Rarely  ...             Low               2
# 4       Non-Travel  ...            None            Poor
# ..             ...  ...             ...             ...
# 995  Travel_Rarely  ...               3               4
# 996         Rarely  ...               1            None
# 997         Rarely  ...               1            None
# 998           None  ...               3               2
# 999     Non-Travel  ...               3               1
#
#     EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                         3                    None                    4
# 1                         3                    None                 None
# 2                         2                    None                    4
# 3                      None                       4                    8
# 4                         4                    None                 None
# ..                      ...                     ...                  ...
# 995                       2                       0                 None
# 996                       4                    None                 None
# 997                       4                    None                 None
# 998                    Good                    None                    0
# 999                       1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 5: JobRole
# Issues Identified:
#
# Extra spaces
#
# Inconsistent case

# %%
df["JobRole"].unique()
# Out:
# array(['Executive ', 'Laboratory Technician', 'Manager', 'Scientist',
#        'Tech', None, 'Research Scientist', 'Executive'], dtype=object)

# %%
def clean_jobrole(df):
    df["JobRole"] = df["JobRole"].str.strip().str.title()
    # handling null values
    df["JobRole"] =df["JobRole"].fillna(df["JobRole"].mode()[0])
    df["JobRole"] =  df["JobRole"].replace("Tech","Technician")
    return df


clean_jobrole(df)
# Out:
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender MonthlyIncome  DateOfJoining OverTime  \
# 0                Executive    None          8699  Not Available       No
# 1    Laboratory Technician    male         12125           None      yes
# 2                  Manager  Female          None     12-05-2018        Y
# 3                Scientist    male          9831     2019-07-28      Yes
# 4               Technician    Male          None  Not Available       No
# ..                     ...     ...           ...            ...      ...
# 995     Research Scientist    Male         19004     12-05-2018        N
# 996              Executive       M          7532     12-05-2018      Yes
# 997              Executive  Female         13545  Not Available      Yes
# 998     Research Scientist    Male         10829           None        N
# 999              Executive       F         19252           None       No
#
#     BusinessTravel  ... JobSatisfaction WorkLifeBalance  \
# 0       Non-Travel  ...               2               1
# 1    Travel_Rarely  ...               4               2
# 2             None  ...               3               3
# 3           Rarely  ...             Low               2
# 4       Non-Travel  ...            None            Poor
# ..             ...  ...             ...             ...
# 995  Travel_Rarely  ...               3               4
# 996         Rarely  ...               1            None
# 997         Rarely  ...               1            None
# 998           None  ...               3               2
# 999     Non-Travel  ...               3               1
#
#     EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                         3                    None                    4
# 1                         3                    None                 None
# 2                         2                    None                    4
# 3                      None                       4                    8
# 4                         4                    None                 None
# ..                      ...                     ...                  ...
# 995                       2                       0                 None
# 996                       4                    None                 None
# 997                       4                    None                 None
# 998                    Good                    None                    0
# 999                       1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 6: Gender
# Issues Identified:
#
# Case inconsistency
#
# Missing values

# %%
def clean_gender(df):
    df["Gender"] = df["Gender"].str.strip().str.title()
    # handling null values
    df["Gender"] = df["Gender"].fillna(df["Gender"].mode()[0])
    df["Gender"] =  df["Gender"].replace({"F":"Female","M":"Male"})
    return df

clean_gender(df)
# Out:
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender MonthlyIncome  DateOfJoining OverTime  \
# 0                Executive    Male          8699  Not Available       No
# 1    Laboratory Technician    Male         12125           None      yes
# 2                  Manager  Female          None     12-05-2018        Y
# 3                Scientist    Male          9831     2019-07-28      Yes
# 4               Technician    Male          None  Not Available       No
# ..                     ...     ...           ...            ...      ...
# 995     Research Scientist    Male         19004     12-05-2018        N
# 996              Executive    Male          7532     12-05-2018      Yes
# 997              Executive  Female         13545  Not Available      Yes
# 998     Research Scientist    Male         10829           None        N
# 999              Executive  Female         19252           None       No
#
#     BusinessTravel  ... JobSatisfaction WorkLifeBalance  \
# 0       Non-Travel  ...               2               1
# 1    Travel_Rarely  ...               4               2
# 2             None  ...               3               3
# 3           Rarely  ...             Low               2
# 4       Non-Travel  ...            None            Poor
# ..             ...  ...             ...             ...
# 995  Travel_Rarely  ...               3               4
# 996         Rarely  ...               1            None
# 997         Rarely  ...               1            None
# 998           None  ...               3               2
# 999     Non-Travel  ...               3               1
#
#     EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                         3                    None                    4
# 1                         3                    None                 None
# 2                         2                    None                    4
# 3                      None                       4                    8
# 4                         4                    None                 None
# ..                      ...                     ...                  ...
# 995                       2                       0                 None
# 996                       4                    None                 None
# 997                       4                    None                 None
# 998                    Good                    None                    0
# 999                       1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 7: MonthlyIncome
# Issues Identified:
#
# Missing values
#
# Needs to be numeric

# %%
def clean_MonthlyIncome(Data):
    def convert_MonthlyIncome(x):
        try:
            return float(x)
        except:
            if isinstance(x,str) and x.lower() == "five thousand":
                return 5000
            return None
    Data["MonthlyIncome"] = Data["MonthlyIncome"].apply(convert_MonthlyIncome)

    # handling null values
    Data["MonthlyIncome"] = Data["MonthlyIncome"].fillna(Data["MonthlyIncome"].median())
    return df

clean_MonthlyIncome(df)
# Out:
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome  DateOfJoining OverTime  \
# 0                Executive    Male         8699.0  Not Available       No
# 1    Laboratory Technician    Male        12125.0           None      yes
# 2                  Manager  Female         5000.0     12-05-2018        Y
# 3                Scientist    Male         9831.0     2019-07-28      Yes
# 4               Technician    Male         5000.0  Not Available       No
# ..                     ...     ...            ...            ...      ...
# 995     Research Scientist    Male        19004.0     12-05-2018        N
# 996              Executive    Male         7532.0     12-05-2018      Yes
# 997              Executive  Female        13545.0  Not Available      Yes
# 998     Research Scientist    Male        10829.0           None        N
# 999              Executive  Female        19252.0           None       No
#
#     BusinessTravel  ... JobSatisfaction WorkLifeBalance  \
# 0       Non-Travel  ...               2               1
# 1    Travel_Rarely  ...               4               2
# 2             None  ...               3               3
# 3           Rarely  ...             Low               2
# 4       Non-Travel  ...            None            Poor
# ..             ...  ...             ...             ...
# 995  Travel_Rarely  ...               3               4
# 996         Rarely  ...               1            None
# 997         Rarely  ...               1            None
# 998           None  ...               3               2
# 999     Non-Travel  ...               3               1
#
#     EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                         3                    None                    4
# 1                         3                    None                 None
# 2                         2                    None                    4
# 3                      None                       4                    8
# 4                         4                    None                 None
# ..                      ...                     ...                  ...
# 995                       2                       0                 None
# 996                       4                    None                 None
# 997                       4                    None                 None
# 998                    Good                    None                    0
# 999                       1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %%
df["MonthlyIncome"].unique()
# Out:
# array([ 8699., 12125.,  5000.,  9831.,  6776., 15483.,  9349., 12435.,
#         4373.,  6926., 11132.,  9325., 18873.,  4500., 17258.,  5753.,
#         3436.,  6837., 11995., 13696., 19971., 15458.,  6820., 13027.,
#        10279., 19288.,  5393., 13344.,  7945., 19074.,  4271.,  9090.,
#         8929., 10635., 19272., 17450.,  4206.,  7187., 11595., 19561.,
#         4819.,  3300., 18160.,  2142., 13538., 18093., 19943.,  7451.,
#        17363.,  7478.,  3609.,  6990., 12561., 18268.,  8662.,  4203.,
#        10301., 10841., 19291.,  4424.,  8204., 16527., 14163.,  7337.,
#        15955.,  4281.,  7349., 17423.,  7407.,  7660., 18209.,  6556.,
#        15960.,  9342., 11675.,  7309.,  4617., 19035.,  6490., 11159.,
#         5796., 17685.,  8233., 11991.,  5939., 13963.,  6285., 11996.,
#        14061., 18195.,  5483.,  8427., 19800., 12011., 11621., 17196.,
#        13813., 19772.,  5860., 18872.,  8553., 15364., 16789., 14010.,
#         5385., 12694., 14386., 15769., 16147., 11788., 19695.,  7751.,
#         9774.,  9459.,  3649., 16750., 18689., 12961.,  3493.,  7256.,
#         5402.,  9621.,  7191., 17028., 18444., 15615.,  5945., 15215.,
#        19129.,  2232.,  3373.,  3602., 13587., 11762., 11905., 15087.,
#        17102., 12703., 10367.,  8065.,  9829.,  2780., 19187., 19765.,
#        13652., 15785.,  2207.,  7615., 18634.,  6555.,  7343., 13045.,
#         4070.,  5269., 13839., 17620., 11710., 19871., 18615., 16002.,
#         3261., 10780.,  6334.,  2804.,  2796., 19504.,  9608.,  6639.,
#         2412., 15697.,  3894.,  2297., 10804., 17354.,  6416.,  9010.,
#        12420., 18856., 11795.,  7978., 14942.,  9241.,  6223.,  2427.,
#         9581., 13172.,  8915.,  7949.,  9811., 10580., 17624.,  4313.,
#         9576., 11705., 10056., 15481., 16284.,  8145., 12659., 16249.,
#        17553., 14966., 13439., 11005., 17895., 18369., 11769., 15651.,
#        17242., 10219., 15604., 13720.,  8789., 13436.,  9244.,  8966.,
#         2992., 11959., 18565.,  6117., 19878., 12556., 11137., 18054.,
#         8835., 10014., 10732., 14430., 16877.,  6356.,  9936.,  2941.,
#         2161., 17360., 14294., 12007., 12514., 12226., 11960., 16295.,
#        14676.,  2995., 10195.,  5038., 16812.,  8847.,  9822., 15980.,
#         4952., 10164.,  7192., 14779., 15548.,  9586., 14152.,  8941.,
#         3126.,  8432., 11443.,  9422., 14902., 11890., 17278.,  7873.,
#        12894., 15824.,  8907., 12410., 12036., 12660.,  3123.,  2448.,
#         2334., 18920.,  2113., 12099.,  7484., 13611., 12095., 16755.,
#         2664.,  6864., 18412., 14584.,  4768., 10670.,  5478., 18221.,
#        17997.,  3869., 15983.,  2249., 13290.,  9389.,  7738.,  3559.,
#        14031., 13022., 17666., 18721.,  5743.,  4182.,  9745., 15947.,
#         7054., 19738.,  3212., 16697., 19104., 10797.,  9358., 11152.,
#        13631., 10162., 15034.,  7382.,  6913.,  4336., 13639.,  8051.,
#        11294.,  6213., 17173.,  8187., 13539., 17399.,  7232., 17015.,
#        13786., 17981.,  5354., 14891., 10809.,  7596.,  2203., 13463.,
#        11599.,  9826.,  2217., 13725., 14587., 19004.,  7532., 13545.,
#        10829., 19252.])

# %% [markdown]
# # Feature 8: DateOfJoining
# Issues Identified:
#
# Wrong date format
#
# Invalid entries like 'Not Available'

# %%
df["DateOfJoining"].isnull().sum()
# Out:
# 267

# %%
def clean_DateOfJoining(Data):
    def convert_DateOfJoining(x):
        try:
            return pd.to_datetime(x,errors="coerce")
        except:
            return pd.NaT
    Data["DateOfJoining"] = Data["DateOfJoining"].apply(convert_DateOfJoining)
    Data["DateOfJoining"] = Data["DateOfJoining"].fillna(Data["DateOfJoining"].median())
    
    return df

clean_DateOfJoining(df)
# Out:
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05       No
# 1    Laboratory Technician    Male        12125.0    2018-12-05      yes
# 2                  Manager  Female         5000.0    2018-12-05        Y
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05       No
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05        N
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05        N
# 999              Executive  Female        19252.0    2018-12-05       No
#
#     BusinessTravel  ... JobSatisfaction WorkLifeBalance  \
# 0       Non-Travel  ...               2               1
# 1    Travel_Rarely  ...               4               2
# 2             None  ...               3               3
# 3           Rarely  ...             Low               2
# 4       Non-Travel  ...            None            Poor
# ..             ...  ...             ...             ...
# 995  Travel_Rarely  ...               3               4
# 996         Rarely  ...               1            None
# 997         Rarely  ...               1            None
# 998           None  ...               3               2
# 999     Non-Travel  ...               3               1
#
#     EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                         3                    None                    4
# 1                         3                    None                 None
# 2                         2                    None                    4
# 3                      None                       4                    8
# 4                         4                    None                 None
# ..                      ...                     ...                  ...
# 995                       2                       0                 None
# 996                       4                    None                 None
# 997                       4                    None                 None
# 998                    Good                    None                    0
# 999                       1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 9: OverTime
# Issues Identified:
#
# Inconsistent case
#
# Variants like 'yes', 'Yes', 'Y', etc.

# %%
df["OverTime"].value_counts()
# Out:
# OverTime
# yes    176
# No     172
# Yes    161
# Y      159
# N      158
# Name: count, dtype: int64

# %%
def clean_category(df,col,li):
    df[col] = df[col].str.strip().str.title()
    # handling null values
    df[col] = df[col].map(li)
    df[col] = df[col].fillna(df[col].mode()[0])
    df[col] = df[col].astype("category")
    return df

clean_category(df,"OverTime",{"Y":"Yes","yes":"Yes","N":"No","no":"No"})
# Out:
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#     BusinessTravel  ... JobSatisfaction WorkLifeBalance  \
# 0       Non-Travel  ...               2               1
# 1    Travel_Rarely  ...               4               2
# 2             None  ...               3               3
# 3           Rarely  ...             Low               2
# 4       Non-Travel  ...            None            Poor
# ..             ...  ...             ...             ...
# 995  Travel_Rarely  ...               3               4
# 996         Rarely  ...               1            None
# 997         Rarely  ...               1            None
# 998           None  ...               3               2
# 999     Non-Travel  ...               3               1
#
#     EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                         3                    None                    4
# 1                         3                    None                 None
# 2                         2                    None                    4
# 3                      None                       4                    8
# 4                         4                    None                 None
# ..                      ...                     ...                  ...
# 995                       2                       0                 None
# 996                       4                    None                 None
# 997                       4                    None                 None
# 998                    Good                    None                    0
# 999                       1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 10: BusinessTravel
# Issues Identified:
#
# Missing values
#
# Inconsistent text formatting

# %%
df['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        189
# Frequently           176
# Rarely               170
# Non-Travel           161
# Travel_Frequently    139
# Name: count, dtype: int64

# %%
clean_category(df,"BusinessTravel",{"Rarely":"Travel_Rarely","Frequently":"Travel_Frequently"})
# Out:
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction WorkLifeBalance  \
# 0    Travel_Frequently  ...               2               1
# 1    Travel_Frequently  ...               4               2
# 2    Travel_Frequently  ...               3               3
# 3        Travel_Rarely  ...             Low               2
# 4    Travel_Frequently  ...            None            Poor
# ..                 ...  ...             ...             ...
# 995  Travel_Frequently  ...               3               4
# 996      Travel_Rarely  ...               1            None
# 997      Travel_Rarely  ...               1            None
# 998  Travel_Frequently  ...               3               2
# 999  Travel_Frequently  ...               3               1
#
#     EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                         3                    None                    4
# 1                         3                    None                 None
# 2                         2                    None                    4
# 3                      None                       4                    8
# 4                         4                    None                 None
# ..                      ...                     ...                  ...
# 995                       2                       0                 None
# 996                       4                    None                 None
# 997                       4                    None                 None
# 998                    Good                    None                    0
# 999                       1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 11: MaritalStatus
# Issues Identified:
#
# Missing values
#
# Inconsistent case

# %%
df["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# M           151
# single      149
# Married     147
# Single      141
# D           136
# Divorced    133
# Name: count, dtype: int64

# %%
clean_category(df,"MaritalStatus",{"D":"Divorced","M":"Married","Single":"Single"})
# Out:
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction WorkLifeBalance  \
# 0    Travel_Frequently  ...               2               1
# 1    Travel_Frequently  ...               4               2
# 2    Travel_Frequently  ...               3               3
# 3        Travel_Rarely  ...             Low               2
# 4    Travel_Frequently  ...            None            Poor
# ..                 ...  ...             ...             ...
# 995  Travel_Frequently  ...               3               4
# 996      Travel_Rarely  ...               1            None
# 997      Travel_Rarely  ...               1            None
# 998  Travel_Frequently  ...               3               2
# 999  Travel_Frequently  ...               3               1
#
#     EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                         3                    None                    4
# 1                         3                    None                 None
# 2                         2                    None                    4
# 3                      None                       4                    8
# 4                         4                    None                 None
# ..                      ...                     ...                  ...
# 995                       2                       0                 None
# 996                       4                    None                 None
# 997                       4                    None                 None
# 998                    Good                    None                    0
# 999                       1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %%
df["MaritalStatus"].unique()
# Out:
# ['Married', 'Divorced', 'Single']
# Categories (3, object): ['Divorced', 'Married', 'Single']

# %% [markdown]
# # Feature 12: YearsAtCompany
# Issues Identified:
#
# Missing values
#
# Non-numeric values (if any)

# %%
df["YearsAtCompany"].unique()
# Out:
# array(['1', None, 'Ten', '9', '2', '3', '13', '8', '20', '5', '7', '10',
#        '4', '15', '19', '6', '11', '17', '12', '14', '18', '0', '16'],
#       dtype=object)

# %%
def clean_YearsAtCompany(Data):
    def convert_YearsAtCompany(x):
        try:
            return pd.to_numeric(x,errors="coerce")
        except:
            if isinstance(x,str) and x.lower() == "ten":
                return 10
            return None 
    Data["YearsAtCompany"] = Data["YearsAtCompany"].apply(convert_YearsAtCompany)
    Data["YearsAtCompany"] = Data["YearsAtCompany"].fillna(Data["YearsAtCompany"].median())
    
    return df

clean_YearsAtCompany(df)
# Out:
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...               2                1
# 1    Travel_Frequently  ...               4                2
# 2    Travel_Frequently  ...               3                3
# 3        Travel_Rarely  ...             Low                2
# 4    Travel_Frequently  ...            None             Poor
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...               3                4
# 996      Travel_Rarely  ...               1             None
# 997      Travel_Rarely  ...               1             None
# 998  Travel_Frequently  ...               3                2
# 999  Travel_Frequently  ...               3                1
#
#     EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                         3                    None                    4
# 1                         3                    None                 None
# 2                         2                    None                    4
# 3                      None                       4                    8
# 4                         4                    None                 None
# ..                      ...                     ...                  ...
# 995                       2                       0                 None
# 996                       4                    None                 None
# 997                       4                    None                 None
# 998                    Good                    None                    0
# 999                       1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %%
df["YearsAtCompany"].unique()
# Out:
# array([ 1., 10.,  9.,  2.,  3., 13.,  8., 20.,  5.,  7.,  4., 15., 19.,
#         6., 11., 17., 12., 14., 18.,  0., 16.])

# %% [markdown]
# # Feature 13: DistanceFromHome
# Issues Identified:
#
# Missing values

# %%
def clean_distance_from_home(df):
    df["DistanceFromHome"] = df["DistanceFromHome"].replace({"Far":"50","Near":"0"})
    df['DistanceFromHome'] = pd.to_numeric(df['DistanceFromHome'], errors='coerce')
    df['DistanceFromHome'].fillna(df['DistanceFromHome'].median(), inplace=True)
    return df

clean_distance_from_home(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_19544\2943858416.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DistanceFromHome'].fillna(df['DistanceFromHome'].median(), inplace=True)
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...               2                1
# 1    Travel_Frequently  ...               4                2
# 2    Travel_Frequently  ...               3                3
# 3        Travel_Rarely  ...             Low                2
# 4    Travel_Frequently  ...            None             Poor
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...               3                4
# 996      Travel_Rarely  ...               1             None
# 997      Travel_Rarely  ...               1             None
# 998  Travel_Frequently  ...               3                2
# 999  Travel_Frequently  ...               3                1
#
#      EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                          3                    None                    4
# 1                          3                    None                 None
# 2                          2                    None                    4
# 3                       None                       4                    8
# 4                          4                    None                 None
# ..                       ...                     ...                  ...
# 995                        2                       0                 None
# 996                        4                    None                 None
# 997                        4                    None                 None
# 998                     Good                    None                    0
# 999                        1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %%
df["DistanceFromHome"].unique()
# Out:
# array([50.,  0., 14., 15., 18., 12., 30.,  3.,  1., 20.,  5., 27., 16.,
#         2., 10.,  6., 29., 22., 21.,  7.,  9., 13.,  8.,  4., 19., 23.,
#        28., 26., 25., 24., 17., 11.])

# %% [markdown]
# # Feature 14: PerformanceRating
# Issues Identified:
#
# Missing values
#
# Inconsistent category representation (numeric or text)

# %%
df["PerformanceRating"].value_counts()
# Out:
# PerformanceRating
# High    177
# 4       176
# 3       174
# 1       159
# 2       154
# Name: count, dtype: int64

# %%
def clean_PerformanceRating(df):
    df["PerformanceRating"] = df["PerformanceRating"].replace({"1":"Low","2":"Medium","3":"Normal","4":"High","High":"High"})
    df['PerformanceRating'].fillna(df['PerformanceRating'].mode()[0], inplace=True)
    return df
clean_PerformanceRating(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_19544\595673742.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PerformanceRating'].fillna(df['PerformanceRating'].mode()[0], inplace=True)
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...               2                1
# 1    Travel_Frequently  ...               4                2
# 2    Travel_Frequently  ...               3                3
# 3        Travel_Rarely  ...             Low                2
# 4    Travel_Frequently  ...            None             Poor
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...               3                4
# 996      Travel_Rarely  ...               1             None
# 997      Travel_Rarely  ...               1             None
# 998  Travel_Frequently  ...               3                2
# 999  Travel_Frequently  ...               3                1
#
#      EnvironmentSatisfaction YearsSinceLastPromotion YearsWithCurrManager  \
# 0                          3                    None                    4
# 1                          3                    None                 None
# 2                          2                    None                    4
# 3                       None                       4                    8
# 4                          4                    None                 None
# ..                       ...                     ...                  ...
# 995                        2                       0                 None
# 996                        4                    None                 None
# 997                        4                    None                 None
# 998                     Good                    None                    0
# 999                        1                       8                   14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 15: TrainingTimesLastYear
# Issues Identified:
#
# Missing values

# %%
df["TrainingTimesLastYear"].unique()
# Out:
# array([None, 'Zero', '5', '0', '2', '6', '4', '3', '1'], dtype=object)

# %%
def clean_training_times(df):
    df["PerformanceRating"] = df["PerformanceRating"].replace({"Zero":"0"})
    df['TrainingTimesLastYear'] = pd.to_numeric(df['TrainingTimesLastYear'], errors='coerce')
    df['TrainingTimesLastYear'].fillna(df['TrainingTimesLastYear'].median(), inplace=True)
    return df

clean_training_times(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_19544\3155066663.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TrainingTimesLastYear'].fillna(df['TrainingTimesLastYear'].median(), inplace=True)
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...               2                1
# 1    Travel_Frequently  ...               4                2
# 2    Travel_Frequently  ...               3                3
# 3        Travel_Rarely  ...             Low                2
# 4    Travel_Frequently  ...            None             Poor
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...               3                4
# 996      Travel_Rarely  ...               1             None
# 997      Travel_Rarely  ...               1             None
# 998  Travel_Frequently  ...               3                2
# 999  Travel_Frequently  ...               3                1
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                          3                    None                     4
# 1                          3                    None                  None
# 2                          2                    None                     4
# 3                       None                       4                     8
# 4                          4                    None                  None
# ..                       ...                     ...                   ...
# 995                        2                       0                  None
# 996                        4                    None                  None
# 997                        4                    None                  None
# 998                     Good                    None                     0
# 999                        1                       8                    14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %%
df["TrainingTimesLastYear"].unique()
# Out:
# array([3., 5., 0., 2., 6., 4., 1.])

# %% [markdown]
# # Feature 16: JobSatisfaction
# Issues Identified:
#
# Mixed type (Numeric and text like 'Low')
#
# Missing values

# %%
df["JobSatisfaction"].unique()
# Out:
# array(['2', '4', '3', 'Low', None, '1'], dtype=object)

# %%
def clean_job_satisfaction(df):
    satisfaction_map = {
        'Low': 1,
        'Medium': 2,
        'High': 3,
        'Very High': 4
    }
    satisfaction_map_1= {
        1:'Low',
        2:'Medium',
        3:'High',
        4:'Very High',
    }
    
    def map_satisfaction(x):
        try:
            return int(x)
        except:
            return satisfaction_map.get(str(x).title(), None)
    
    df['JobSatisfaction'] = df['JobSatisfaction'].apply(map_satisfaction)
    df['JobSatisfaction'] = df['JobSatisfaction'].map(satisfaction_map_1)
    df['JobSatisfaction'].fillna(df['JobSatisfaction'].mode()[0], inplace=True)
    return df

clean_job_satisfaction(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_19544\3564929830.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['JobSatisfaction'].fillna(df['JobSatisfaction'].mode()[0], inplace=True)
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...          Medium                1
# 1    Travel_Frequently  ...       Very High                2
# 2    Travel_Frequently  ...            High                3
# 3        Travel_Rarely  ...             Low                2
# 4    Travel_Frequently  ...             Low             Poor
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...            High                4
# 996      Travel_Rarely  ...             Low             None
# 997      Travel_Rarely  ...             Low             None
# 998  Travel_Frequently  ...            High                2
# 999  Travel_Frequently  ...            High                1
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                          3                    None                     4
# 1                          3                    None                  None
# 2                          2                    None                     4
# 3                       None                       4                     8
# 4                          4                    None                  None
# ..                       ...                     ...                   ...
# 995                        2                       0                  None
# 996                        4                    None                  None
# 997                        4                    None                  None
# 998                     Good                    None                     0
# 999                        1                       8                    14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 17: WorkLifeBalance
# Issues Identified:
#
# Contains text like "Poor", "Good" etc.
#
# Missing values

# %%
df["WorkLifeBalance"].unique()
# Out:
# array(['1', '2', '3', 'Poor', None, '4'], dtype=object)

# %%
def clean_job_satisfaction(df):
    satisfaction_map= {
        1:'Bad',
        2:'Poor',
        3:'Good',
        4:'Excellent',
    }    
    df["WorkLifeBalance"] = df["WorkLifeBalance"].replace("Poor","4")
    df["WorkLifeBalance"] = pd.to_numeric(df["WorkLifeBalance"],errors="coerce")
    df['WorkLifeBalance'] = df['WorkLifeBalance'].map(satisfaction_map)
    df['WorkLifeBalance'].fillna(df['WorkLifeBalance'].mode()[0], inplace=True)
    return df

clean_job_satisfaction(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_19544\3190851201.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WorkLifeBalance'].fillna(df['WorkLifeBalance'].mode()[0], inplace=True)
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...          Medium              Bad
# 1    Travel_Frequently  ...       Very High             Poor
# 2    Travel_Frequently  ...            High             Good
# 3        Travel_Rarely  ...             Low             Poor
# 4    Travel_Frequently  ...             Low        Excellent
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...            High        Excellent
# 996      Travel_Rarely  ...             Low        Excellent
# 997      Travel_Rarely  ...             Low        Excellent
# 998  Travel_Frequently  ...            High             Poor
# 999  Travel_Frequently  ...            High              Bad
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                          3                    None                     4
# 1                          3                    None                  None
# 2                          2                    None                     4
# 3                       None                       4                     8
# 4                          4                    None                  None
# ..                       ...                     ...                   ...
# 995                        2                       0                  None
# 996                        4                    None                  None
# 997                        4                    None                  None
# 998                     Good                    None                     0
# 999                        1                       8                    14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 18: EnvironmentSatisfaction
# Issues Identified:
#
# Numeric & categorical mix
#
# Missing values

# %%
df["EnvironmentSatisfaction"].value_counts()
# Out:
# EnvironmentSatisfaction
# 1       180
# 2       178
# 4       173
# Good    170
# 3       163
# Name: count, dtype: int64

# %%
def clean_job_satisfaction(df):
    satisfaction_map= {
        1:'Bad',
        2:'Poor',
        3:'Good',
        4:'Excellent',
    }    
    df["EnvironmentSatisfaction"] = df["EnvironmentSatisfaction"].replace({"Good":"1"})
    df["EnvironmentSatisfaction"] = pd.to_numeric(df["EnvironmentSatisfaction"],errors="coerce")
    df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].map(satisfaction_map)
    df['EnvironmentSatisfaction'].fillna(df['EnvironmentSatisfaction'].mode()[0], inplace=True)
    return df

clean_job_satisfaction(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_19544\2979859941.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['EnvironmentSatisfaction'].fillna(df['EnvironmentSatisfaction'].mode()[0], inplace=True)
#     EmployeeID   Age              Department      Education  \
# 0       2632.0  13.0  Research & Development       Bachelor
# 1       1621.0  31.0         Human Resources       Bachelor
# 2       5665.0  38.0  Research & Development        College
# 3         None  13.0                 Unknown         Master
# 4       2035.0  13.0                   Sales        College
# ..         ...   ...                     ...            ...
# 995     8129.0  41.0  Research & Development  Below College
# 996     6899.0  23.0                   Sales          Other
# 997       None  13.0                 Unknown        College
# 998     1155.0  13.0  Research & Development       Bachelor
# 999     3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...          Medium              Bad
# 1    Travel_Frequently  ...       Very High             Poor
# 2    Travel_Frequently  ...            High             Good
# 3        Travel_Rarely  ...             Low             Poor
# 4    Travel_Frequently  ...             Low        Excellent
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...            High        Excellent
# 996      Travel_Rarely  ...             Low        Excellent
# 997      Travel_Rarely  ...             Low        Excellent
# 998  Travel_Frequently  ...            High             Poor
# 999  Travel_Frequently  ...            High              Bad
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                       Good                    None                     4
# 1                       Good                    None                  None
# 2                       Poor                    None                     4
# 3                        Bad                       4                     8
# 4                  Excellent                    None                  None
# ..                       ...                     ...                   ...
# 995                     Poor                       0                  None
# 996                Excellent                    None                  None
# 997                Excellent                    None                  None
# 998                      Bad                    None                     0
# 999                      Bad                       8                    14
#
#     JobInvolvement Attrition StockOptionLevel PercentSalaryHike  \
# 0                3       Yes             Zero                19
# 1                4       yes                2              None
# 2                4      None                0              None
# 3                4       Yes                1              None
# 4                4      None             Zero                15
# ..             ...       ...              ...               ...
# 995           None         Y                2                23
# 996              4        No             None                21
# 997              1       Yes                3              None
# 998           High       Yes                3                11
# 999              1       Yes                3                11
#
#     TotalWorkingYears
# 0                  \r
# 1                 5\r
# 2                13\r
# 3            Twenty\r
# 4            Twenty\r
# ..                ...
# 995          Twenty\r
# 996          Twenty\r
# 997                \r
# 998          Twenty\r
# 999                \r
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 19: YearsSinceLastPromotion
# Issues Identified:
#
# Non-numeric like 'None'
#
# Missing values

# %%
df["YearsSinceLastPromotion"].fillna(df["YearsSinceLastPromotion"].median(),inplace= True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df["YearsSinceLastPromotion"].fillna(df["YearsSinceLastPromotion"].median(),inplace= True)
#
# File c:\python\Lib\site-packages\pandas\core\series.py:6550, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6542 @doc(make_doc("median", ndim=1))
#    6543 def median(
#    6544     self,
#    (...)
#    6548     **kwargs,
#    6549 ):
# -> 6550     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\python\Lib\site-packages\pandas\core\generic.py:12428, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12421 def median(
#   12422     self,
#   12423     axis: Axis | None = 0,
#    (...)
#   12426     **kwargs,
#   12427 ) -> Series | float:
# > 12428     return self._stat_function(
#   12429         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12430     )
#
# File c:\python\Lib\site-packages\pandas\core\generic.py:12374, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12370 nv.validate_func(name, (), kwargs)
#   12372 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12374 return self._reduce(
#   12375     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376 )
#
# File c:\python\Lib\site-packages\pandas\core\series.py:6448, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6443     # GH#47500 - change to TypeError to match other methods
#    6444     raise TypeError(
#    6445         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6446         "with non-numeric dtypes."
#    6447     )
# -> 6448 return op(delegate, skipna=skipna, **kwds)
#
# File c:\python\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\python\Lib\site-packages\pandas\core\nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     785     inferred = lib.infer_dtype(values)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#     789     values = values.astype("f8")
#
# TypeError: Cannot convert [nan 'None' nan '4' 'None' '8' nan nan '0' nan 'None' nan nan nan nan '4'
#  nan '4' '7' 'None' nan 'None' nan '10' '5' 'None' '2' 'None' 'None'
#  'None' nan nan nan nan nan 'None' '2' '4' 'None' 'None' '1' '6' 'None'
#  'None' '3' nan 'None' '8' nan '4' '0' nan nan nan 'None' nan 'None'
#  'None' '7' 'None' 'None' 'None' nan 'None' nan nan nan nan nan '3' '1'
#  nan 'None' '10' nan '10' 'None' 'None' '9' nan '3' 'None' nan '9' 'None'
#  'None' '1' nan nan 'None' '2' 'None' nan 'None' nan 'None' '2' '0' '10'
#  '8' 'None' '10' nan '1' '10' nan nan nan nan nan nan '8' '10' nan 'None'
#  nan 'None' '10' 'None' '1' nan nan '0' nan 'None' '10' nan 'None' nan '7'
#  'None' '3' 'None' '0' 'None' '6' '10' '1' '7' nan '9' nan nan 'None' nan
#  nan '9' 'None' 'None' 'None' '7' nan nan nan 'None' '0' '0' '5' nan
#  'None' 'None' 'None' nan nan 'None' 'None' nan '4' 'None' nan 'None'
#  'None' 'None' nan nan 'None' nan nan '0' 'None' '9' '7' '0' 'None' 'None'
#  'None' '0' 'None' '10' 'None' nan 'None' nan '9' nan '1' '3' 'None' nan
#  nan '9' 'None' '3' '9' '1' '0' 'None' '4' 'None' 'None' '6' '5' '5' '3'
#  nan '2' nan '0' nan '10' 'None' 'None' '0' 'None' '4' 'None' nan '9' '2'
#  '8' nan '3' nan '2' 'None' 'None' nan '2' 'None' 'None' '6' '10' 'None'
#  nan '10' '0' nan nan nan 'None' nan 'None' 'None' 'None' nan nan nan nan
#  nan 'None' '4' nan '1' nan '5' 'None' 'None' 'None' nan 'None' '4' nan
#  nan '0' 'None' '4' '6' '9' '9' 'None' 'None' 'None' 'None' nan 'None' '9'
#  nan nan 'None' nan 'None' nan 'None' '0' nan 'None' 'None' 'None' 'None'
#  nan '4' nan '3' nan nan '0' '6' 'None' '7' 'None' 'None' nan '9' nan
#  'None' '6' nan nan 'None' 'None' 'None' 'None' 'None' '0' 'None' '3'
#  'None' 'None' 'None' '6' 'None' '4' nan '7' '6' 'None' '8' 'None' '7' nan
#  'None' '2' '4' nan 'None' 'None' nan 'None' '3' nan '1' nan nan nan nan
#  '7' nan nan '5' 'None' 'None' nan '3' '9' 'None' 'None' '9' 'None' 'None'
#  'None' nan nan '6' nan '1' '3' nan 'None' '2' nan nan 'None' nan 'None'
#  nan '2' nan '2' '3' '0' 'None' '6' 'None' '10' 'None' '9' 'None' nan
#  'None' 'None' 'None' nan nan '4' nan 'None' nan nan nan 'None' nan 'None'
#  '0' 'None' '6' nan 'None' '0' nan 'None' 'None' nan nan 'None' '9' nan
#  'None' nan 'None' 'None' nan 'None' 'None' '7' '8' 'None' '10' nan '3'
#  '1' nan '3' nan '10' 'None' nan nan nan '5' nan '9' nan '8' '3' nan
#  'None' nan 'None' nan nan '0' 'None' '6' 'None' '5' 'None' 'None' '1'
#  'None' 'None' '10' '10' '10' nan '1' nan 'None' 'None' nan nan 'None' nan
#  nan 'None' '4' 'None' 'None' nan '8' nan 'None' '2' '7' '4' 'None' '3'
#  '0' nan 'None' 'None' '3' '4' nan '5' '8' 'None' nan nan '5' '3' nan nan
#  'None' 'None' 'None' nan '8' nan 'None' nan '6' '5' nan '10' '10' nan
#  'None' 'None' 'None' 'None' '6' 'None' '4' '5' 'None' '2' nan 'None' '6'
#  'None' nan nan nan nan '9' 'None' '6' 'None' nan nan '2' 'None' nan '1'
#  nan 'None' 'None' '0' nan 'None' nan 'None' nan '1' '4' nan 'None' '5'
#  nan nan 'None' 'None' 'None' 'None' 'None' nan nan 'None' '7' nan nan nan
#  'None' 'None' 'None' '5' '7' 'None' '2' nan nan '6' nan '2' 'None' '4'
#  'None' '5' '5' nan '8' nan nan nan 'None' nan nan '0' '0' nan '5' 'None'
#  'None' nan '10' nan nan nan '10' nan '0' nan 'None' nan 'None' 'None'
#  'None' '6' '10' nan nan nan nan nan '3' nan '8' '6' 'None' '10' nan
#  'None' nan '9' 'None' 'None' '0' nan '4' '4' 'None' nan 'None' '2' nan
#  '0' 'None' 'None' 'None' '5' nan nan 'None' 'None' '5' nan '9' '4' nan
#  'None' nan '7' '10' 'None' 'None' nan '5' nan nan '6' '5' '2' '7' 'None'
#  nan nan '9' 'None' nan 'None' '2' nan nan nan '4' 'None' 'None' '6' '6'
#  'None' '3' '10' nan '6' 'None' '2' '10' nan 'None' nan nan 'None' '4' '7'
#  '0' nan 'None' 'None' nan nan '4' '1' 'None' '6' '7' nan nan 'None' nan
#  '10' nan nan nan 'None' nan '4' '7' 'None' 'None' '6' '1' nan '5' 'None'
#  'None' '9' 'None' nan nan '8' 'None' 'None' nan 'None' '0' nan '4' '3'
#  nan '2' nan 'None' nan nan 'None' 'None' nan '5' 'None' nan '9' nan
#  'None' 'None' '0' '4' nan nan '6' 'None' '6' nan '3' '0' 'None' '3' nan
#  'None' '8' 'None' 'None' '9' 'None' '9' '8' '7' '2' nan '7' '0' 'None'
#  nan '10' 'None' 'None' 'None' 'None' '5' nan '1' nan nan '3' '1' 'None'
#  nan nan nan nan nan 'None' 'None' '0' '4' '6' 'None' '10' 'None' nan '8'
#  '7' 'None' nan nan '0' '9' '3' '8' '2' 'None' nan '9' 'None' 'None' nan
#  nan nan 'None' '2' 'None' '6' 'None' '2' nan nan 'None' 'None' '0' 'None'
#  '4' 'None' 'None' '9' nan nan '9' '3' '10' '5' '6' nan '2' '9' 'None'
#  'None' 'None' 'None' nan 'None' nan 'None' '7' '6' 'None' '8' nan '0' nan
#  '2' '9' nan '2' 'None' '4' '7' 'None' 'None' 'None' nan '1' nan nan '8'
#  'None' 'None' '4' '1' 'None' '2' 'None' nan nan 'None' 'None' 'None'
#  'None' nan '0' nan '1' '4' 'None' nan nan nan nan nan '3' '5' 'None'
#  'None' '4' 'None' nan nan 'None' 'None' 'None' '8' nan 'None' nan 'None'
#  '1' 'None' 'None' nan 'None' '10' '1' nan nan '0' '4' 'None' nan 'None'
#  'None' '4' nan '9' 'None' '2' 'None' nan '0' nan nan 'None' '10' nan '5'
#  '8' 'None' nan nan '5' nan 'None' 'None' 'None' nan '0' 'None' '7' nan
#  '1' 'None' 'None' '1' 'None' '2' nan nan '4' '0' 'None' nan 'None' '8'] to numeric

# %%
df["YearsSinceLastPromotion"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Feature 20: YearsWithCurrManager
# Issues Identified:
#
# Missing values
#
# Non-numeric (if any)

# %%
df["YearsWithCurrManager"].unique()
# Out:
# array(['4', nan, '8', 'Five', '13', '1', '0', '11', '9', '15', '6', '14',
#        '7', '3', '12', '10', '5', '2'], dtype=object)

# %%
def clean_years_with_curr_manager(df):
    df["YearsWithCurrManager"] = df["YearsWithCurrManager"].replace({"Five":"5"})
    df['YearsWithCurrManager'] = pd.to_numeric(df['YearsWithCurrManager'], errors='coerce')
    df['YearsWithCurrManager'].fillna(df['YearsWithCurrManager'].median(), inplace=True)
    return df

df = clean_years_with_curr_manager(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_6648\217045556.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['YearsWithCurrManager'].fillna(df['YearsWithCurrManager'].median(), inplace=True)

# %% [markdown]
# # Feature 21: JobInvolvement
# Issues Identified:
#
# Numeric or Text category mapping
#
# Missing values

# %%
df["JobInvolvement"].unique()
# Out:
# array(['3', '4', '1', nan, 'High', '2'], dtype=object)

# %%
def clean_JobInvolvement(df):
    satisfaction_map= {
        1:'Minimal',
        2:'Moderate',
        3:'Strong',
        4:'Extremely',
    }    
    df["JobInvolvement"] = df["JobInvolvement"].replace({"High":"1"})
    df["JobInvolvement"] = pd.to_numeric(df["JobInvolvement"],errors="coerce")
    df['JobInvolvement'] = df['JobInvolvement'].map(satisfaction_map)
    df['JobInvolvement'].fillna(df['JobInvolvement'].mode()[0], inplace=True)
    return df

clean_JobInvolvement(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_6648\2183430479.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['JobInvolvement'].fillna(df['JobInvolvement'].mode()[0], inplace=True)
#      EmployeeID   Age              Department      Education  \
# 0        2632.0  13.0  Research & Development       Bachelor
# 1        1621.0  31.0         Human Resources       Bachelor
# 2        5665.0  38.0  Research & Development        College
# 3           NaN  13.0                 Unknown         Master
# 4        2035.0  13.0                   Sales        College
# ..          ...   ...                     ...            ...
# 995      8129.0  41.0  Research & Development  Below College
# 996      6899.0  23.0                   Sales          Other
# 997         NaN  13.0                 Unknown        College
# 998      1155.0  13.0  Research & Development       Bachelor
# 999      3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...          Medium              Bad
# 1    Travel_Frequently  ...       Very High             Poor
# 2    Travel_Frequently  ...            High             Good
# 3        Travel_Rarely  ...             Low             Poor
# 4    Travel_Frequently  ...             Low        Excellent
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...            High        Excellent
# 996      Travel_Rarely  ...             Low        Excellent
# 997      Travel_Rarely  ...             Low        Excellent
# 998  Travel_Frequently  ...            High             Poor
# 999  Travel_Frequently  ...            High              Bad
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                       Good                     5.0                   4.0
# 1                       Good                     5.0                   5.0
# 2                       Poor                     5.0                   4.0
# 3                        Bad                     4.0                   8.0
# 4                  Excellent                     5.0                   5.0
# ..                       ...                     ...                   ...
# 995                     Poor                     0.0                   5.0
# 996                Excellent                     5.0                   5.0
# 997                Excellent                     5.0                   5.0
# 998                      Bad                     5.0                   0.0
# 999                      Bad                     8.0                  14.0
#
#     JobInvolvement Attrition StockOptionLevel  PercentSalaryHike  \
# 0           Strong       Yes             Zero                 19
# 1        Extremely       yes                2                NaN
# 2        Extremely       NaN                0                NaN
# 3        Extremely       Yes                1                NaN
# 4        Extremely       NaN             Zero                 15
# ..             ...       ...              ...                ...
# 995        Minimal         Y                2                 23
# 996      Extremely        No              NaN                 21
# 997        Minimal       Yes                3                NaN
# 998        Minimal       Yes                3                 11
# 999        Minimal       Yes                3                 11
#
#      TotalWorkingYears
# 0                  NaN
# 1                    5
# 2                   13
# 3               Twenty
# 4               Twenty
# ..                 ...
# 995             Twenty
# 996             Twenty
# 997                NaN
# 998             Twenty
# 999                NaN
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 22: Attrition
# Issues Identified:
#
# Case inconsistency ('yes', 'Yes', 'No', 'no')
#
# Missing values

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     180
# Yes    171
# Y      169
# yes    168
# N      154
# Name: count, dtype: int64

# %%
def clean_Attrition(df):
    df["Attrition"] = df["Attrition"].replace({"yes":"Yes","Y":"Yes","N":"No"})
    df['Attrition'].fillna(df['Attrition'].mode()[0], inplace=True)
    return df

clean_Attrition(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_6648\3241307932.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attrition'].fillna(df['Attrition'].mode()[0], inplace=True)
#      EmployeeID   Age              Department      Education  \
# 0        2632.0  13.0  Research & Development       Bachelor
# 1        1621.0  31.0         Human Resources       Bachelor
# 2        5665.0  38.0  Research & Development        College
# 3           NaN  13.0                 Unknown         Master
# 4        2035.0  13.0                   Sales        College
# ..          ...   ...                     ...            ...
# 995      8129.0  41.0  Research & Development  Below College
# 996      6899.0  23.0                   Sales          Other
# 997         NaN  13.0                 Unknown        College
# 998      1155.0  13.0  Research & Development       Bachelor
# 999      3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...          Medium              Bad
# 1    Travel_Frequently  ...       Very High             Poor
# 2    Travel_Frequently  ...            High             Good
# 3        Travel_Rarely  ...             Low             Poor
# 4    Travel_Frequently  ...             Low        Excellent
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...            High        Excellent
# 996      Travel_Rarely  ...             Low        Excellent
# 997      Travel_Rarely  ...             Low        Excellent
# 998  Travel_Frequently  ...            High             Poor
# 999  Travel_Frequently  ...            High              Bad
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                       Good                     5.0                   4.0
# 1                       Good                     5.0                   5.0
# 2                       Poor                     5.0                   4.0
# 3                        Bad                     4.0                   8.0
# 4                  Excellent                     5.0                   5.0
# ..                       ...                     ...                   ...
# 995                     Poor                     0.0                   5.0
# 996                Excellent                     5.0                   5.0
# 997                Excellent                     5.0                   5.0
# 998                      Bad                     5.0                   0.0
# 999                      Bad                     8.0                  14.0
#
#     JobInvolvement Attrition StockOptionLevel  PercentSalaryHike  \
# 0           Strong       Yes             Zero                 19
# 1        Extremely       Yes                2                NaN
# 2        Extremely       Yes                0                NaN
# 3        Extremely       Yes                1                NaN
# 4        Extremely       Yes             Zero                 15
# ..             ...       ...              ...                ...
# 995        Minimal       Yes                2                 23
# 996      Extremely        No              NaN                 21
# 997        Minimal       Yes                3                NaN
# 998        Minimal       Yes                3                 11
# 999        Minimal       Yes                3                 11
#
#      TotalWorkingYears
# 0                  NaN
# 1                    5
# 2                   13
# 3               Twenty
# 4               Twenty
# ..                 ...
# 995             Twenty
# 996             Twenty
# 997                NaN
# 998             Twenty
# 999                NaN
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 23: StockOptionLevel
# Issues Identified:
#
# Text like 'Zero', 'None'
#
# Missing values

# %%
df["StockOptionLevel"].unique()
# Out:
# array(['Zero', '2', '0', '1', nan, '3'], dtype=object)

# %%
def clean_stock_option_level(df):
    def convert_option(x):
        try:
            return int(x)
        except:
            if str(x).lower() == 'zero':
                return 0
            if str(x).lower() == 'none':
                return 0
            return None
    
    df['StockOptionLevel'] = df['StockOptionLevel'].apply(convert_option)
    df['StockOptionLevel'].fillna(df['StockOptionLevel'].mode()[0], inplace=True)
    return df

clean_stock_option_level(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_6648\1520101368.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['StockOptionLevel'].fillna(df['StockOptionLevel'].mode()[0], inplace=True)
#      EmployeeID   Age              Department      Education  \
# 0        2632.0  13.0  Research & Development       Bachelor
# 1        1621.0  31.0         Human Resources       Bachelor
# 2        5665.0  38.0  Research & Development        College
# 3           NaN  13.0                 Unknown         Master
# 4        2035.0  13.0                   Sales        College
# ..          ...   ...                     ...            ...
# 995      8129.0  41.0  Research & Development  Below College
# 996      6899.0  23.0                   Sales          Other
# 997         NaN  13.0                 Unknown        College
# 998      1155.0  13.0  Research & Development       Bachelor
# 999      3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...          Medium              Bad
# 1    Travel_Frequently  ...       Very High             Poor
# 2    Travel_Frequently  ...            High             Good
# 3        Travel_Rarely  ...             Low             Poor
# 4    Travel_Frequently  ...             Low        Excellent
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...            High        Excellent
# 996      Travel_Rarely  ...             Low        Excellent
# 997      Travel_Rarely  ...             Low        Excellent
# 998  Travel_Frequently  ...            High             Poor
# 999  Travel_Frequently  ...            High              Bad
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                       Good                     5.0                   4.0
# 1                       Good                     5.0                   5.0
# 2                       Poor                     5.0                   4.0
# 3                        Bad                     4.0                   8.0
# 4                  Excellent                     5.0                   5.0
# ..                       ...                     ...                   ...
# 995                     Poor                     0.0                   5.0
# 996                Excellent                     5.0                   5.0
# 997                Excellent                     5.0                   5.0
# 998                      Bad                     5.0                   0.0
# 999                      Bad                     8.0                  14.0
#
#     JobInvolvement Attrition StockOptionLevel  PercentSalaryHike  \
# 0           Strong       Yes              0.0                 19
# 1        Extremely       Yes              2.0                NaN
# 2        Extremely       Yes              0.0                NaN
# 3        Extremely       Yes              1.0                NaN
# 4        Extremely       Yes              0.0                 15
# ..             ...       ...              ...                ...
# 995        Minimal       Yes              2.0                 23
# 996      Extremely        No              0.0                 21
# 997        Minimal       Yes              3.0                NaN
# 998        Minimal       Yes              3.0                 11
# 999        Minimal       Yes              3.0                 11
#
#      TotalWorkingYears
# 0                  NaN
# 1                    5
# 2                   13
# 3               Twenty
# 4               Twenty
# ..                 ...
# 995             Twenty
# 996             Twenty
# 997                NaN
# 998             Twenty
# 999                NaN
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 24: PercentSalaryHike
# Issues Identified:
#
# Missing values
#
# Non-numeric values (if any)

# %%
df["PercentSalaryHike"].unique()
# Out:
# array(['19', nan, '15', '24', '22', 'Twenty', '23', '18', '12', '25',
#        '14', '17', '16', '10', '21', '13', '20', '11'], dtype=object)

# %%
def clean_PercentSalaryHike(df):
    df["PercentSalaryHike"] = df["PercentSalaryHike"].replace({"Twenty":"20"})
    df["PercentSalaryHike"] = pd.to_numeric(df["PercentSalaryHike"],errors="coerce")
    df['PercentSalaryHike'].fillna(df['PercentSalaryHike'].median(), inplace=True)
    return df

clean_PercentSalaryHike(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_6648\3325280170.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PercentSalaryHike'].fillna(df['PercentSalaryHike'].median(), inplace=True)
#      EmployeeID   Age              Department      Education  \
# 0        2632.0  13.0  Research & Development       Bachelor
# 1        1621.0  31.0         Human Resources       Bachelor
# 2        5665.0  38.0  Research & Development        College
# 3           NaN  13.0                 Unknown         Master
# 4        2035.0  13.0                   Sales        College
# ..          ...   ...                     ...            ...
# 995      8129.0  41.0  Research & Development  Below College
# 996      6899.0  23.0                   Sales          Other
# 997         NaN  13.0                 Unknown        College
# 998      1155.0  13.0  Research & Development       Bachelor
# 999      3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...          Medium              Bad
# 1    Travel_Frequently  ...       Very High             Poor
# 2    Travel_Frequently  ...            High             Good
# 3        Travel_Rarely  ...             Low             Poor
# 4    Travel_Frequently  ...             Low        Excellent
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...            High        Excellent
# 996      Travel_Rarely  ...             Low        Excellent
# 997      Travel_Rarely  ...             Low        Excellent
# 998  Travel_Frequently  ...            High             Poor
# 999  Travel_Frequently  ...            High              Bad
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                       Good                     5.0                   4.0
# 1                       Good                     5.0                   5.0
# 2                       Poor                     5.0                   4.0
# 3                        Bad                     4.0                   8.0
# 4                  Excellent                     5.0                   5.0
# ..                       ...                     ...                   ...
# 995                     Poor                     0.0                   5.0
# 996                Excellent                     5.0                   5.0
# 997                Excellent                     5.0                   5.0
# 998                      Bad                     5.0                   0.0
# 999                      Bad                     8.0                  14.0
#
#     JobInvolvement Attrition StockOptionLevel  PercentSalaryHike  \
# 0           Strong       Yes              0.0               19.0
# 1        Extremely       Yes              2.0               20.0
# 2        Extremely       Yes              0.0               20.0
# 3        Extremely       Yes              1.0               20.0
# 4        Extremely       Yes              0.0               15.0
# ..             ...       ...              ...                ...
# 995        Minimal       Yes              2.0               23.0
# 996      Extremely        No              0.0               21.0
# 997        Minimal       Yes              3.0               20.0
# 998        Minimal       Yes              3.0               11.0
# 999        Minimal       Yes              3.0               11.0
#
#      TotalWorkingYears
# 0                  NaN
# 1                    5
# 2                   13
# 3               Twenty
# 4               Twenty
# ..                 ...
# 995             Twenty
# 996             Twenty
# 997                NaN
# 998             Twenty
# 999                NaN
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Feature 25: TotalWorkingYears
# Issues Identified:
#
# Non-numeric entries like "Twenty"
#
# Missing values

# %%
df["TotalWorkingYears"].unique()
# Out:
# array([nan, '5', '13', 'Twenty', '1', '25', '39', '11', '15', '18', '38',
#        '29', '28', '40', '35', '4', '8', '33', '6', '31', '19', '10',
#        '26', '3', '36', '30', '22', '21', '7', '14', '12', '16', '27',
#        '9', '23', '24', '17', '20', '2', '34', '37', '32'], dtype=object)

# %%
def clean_TotalWorkingYears(df):
    df["TotalWorkingYears"] = df["TotalWorkingYears"].replace({"Twenty":"20"})
    df["TotalWorkingYears"] = pd.to_numeric(df["TotalWorkingYears"],errors="coerce")
    df['TotalWorkingYears'].fillna(df['TotalWorkingYears'].median(), inplace=True)
    return df

clean_TotalWorkingYears(df)
# Out:
# C:\Users\SWAPNIL GAIKWAD\AppData\Local\Temp\ipykernel_6648\3259783406.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TotalWorkingYears'].fillna(df['TotalWorkingYears'].median(), inplace=True)
#      EmployeeID   Age              Department      Education  \
# 0        2632.0  13.0  Research & Development       Bachelor
# 1        1621.0  31.0         Human Resources       Bachelor
# 2        5665.0  38.0  Research & Development        College
# 3           NaN  13.0                 Unknown         Master
# 4        2035.0  13.0                   Sales        College
# ..          ...   ...                     ...            ...
# 995      8129.0  41.0  Research & Development  Below College
# 996      6899.0  23.0                   Sales          Other
# 997         NaN  13.0                 Unknown        College
# 998      1155.0  13.0  Research & Development       Bachelor
# 999      3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 3                Scientist    Male         9831.0    2019-07-28      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# ..                     ...     ...            ...           ...      ...
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 997              Executive  Female        13545.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...          Medium              Bad
# 1    Travel_Frequently  ...       Very High             Poor
# 2    Travel_Frequently  ...            High             Good
# 3        Travel_Rarely  ...             Low             Poor
# 4    Travel_Frequently  ...             Low        Excellent
# ..                 ...  ...             ...              ...
# 995  Travel_Frequently  ...            High        Excellent
# 996      Travel_Rarely  ...             Low        Excellent
# 997      Travel_Rarely  ...             Low        Excellent
# 998  Travel_Frequently  ...            High             Poor
# 999  Travel_Frequently  ...            High              Bad
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                       Good                     5.0                   4.0
# 1                       Good                     5.0                   5.0
# 2                       Poor                     5.0                   4.0
# 3                        Bad                     4.0                   8.0
# 4                  Excellent                     5.0                   5.0
# ..                       ...                     ...                   ...
# 995                     Poor                     0.0                   5.0
# 996                Excellent                     5.0                   5.0
# 997                Excellent                     5.0                   5.0
# 998                      Bad                     5.0                   0.0
# 999                      Bad                     8.0                  14.0
#
#     JobInvolvement Attrition StockOptionLevel  PercentSalaryHike  \
# 0           Strong       Yes              0.0               19.0
# 1        Extremely       Yes              2.0               20.0
# 2        Extremely       Yes              0.0               20.0
# 3        Extremely       Yes              1.0               20.0
# 4        Extremely       Yes              0.0               15.0
# ..             ...       ...              ...                ...
# 995        Minimal       Yes              2.0               23.0
# 996      Extremely        No              0.0               21.0
# 997        Minimal       Yes              3.0               20.0
# 998        Minimal       Yes              3.0               11.0
# 999        Minimal       Yes              3.0               11.0
#
#      TotalWorkingYears
# 0                 20.0
# 1                  5.0
# 2                 13.0
# 3                 20.0
# 4                 20.0
# ..                 ...
# 995               20.0
# 996               20.0
# 997               20.0
# 998               20.0
# 999               20.0
#
# [1000 rows x 25 columns]

# %%
# df.select_dtypes(include="category")
df.isnull().sum()
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# Age                        0
# Department                 0
# Education                  0
# JobRole                    0
# Gender                     0
# MonthlyIncome              0
# DateOfJoining              0
# OverTime                   0
# BusinessTravel             0
# MaritalStatus              0
# YearsAtCompany             0
# DistanceFromHome           0
# PerformanceRating          0
# TrainingTimesLastYear      0
# JobSatisfaction            0
# WorkLifeBalance            0
# EnvironmentSatisfaction    0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# JobInvolvement             0
# Attrition                  0
# StockOptionLevel           0
# PercentSalaryHike          0
# TotalWorkingYears          0
# dtype: int64

# %%
df.to_csv("Attrition cleaned data.csv",index= False)
df
# Out:
#      EmployeeID   Age              Department      Education  \
# 0        2632.0  13.0  Research & Development       Bachelor
# 1        1621.0  31.0         Human Resources       Bachelor
# 2        5665.0  38.0  Research & Development        College
# 4        2035.0  13.0                   Sales        College
# 5        3248.0  21.0         Human Resources         Master
# ..          ...   ...                     ...            ...
# 994      9441.0  52.0                 Unknown         Master
# 995      8129.0  41.0  Research & Development  Below College
# 996      6899.0  23.0                   Sales          Other
# 998      1155.0  13.0  Research & Development       Bachelor
# 999      3233.0  13.0  Research & Development        College
#
#                    JobRole  Gender  MonthlyIncome DateOfJoining OverTime  \
# 0                Executive    Male         8699.0    2018-12-05      Yes
# 1    Laboratory Technician    Male        12125.0    2018-12-05      Yes
# 2                  Manager  Female         5000.0    2018-12-05      Yes
# 4               Technician    Male         5000.0    2018-12-05      Yes
# 5                Executive    Male         6776.0    2016-01-23       No
# ..                     ...     ...            ...           ...      ...
# 994              Executive  Female        14587.0    2018-12-05      Yes
# 995     Research Scientist    Male        19004.0    2018-12-05       No
# 996              Executive    Male         7532.0    2018-12-05      Yes
# 998     Research Scientist    Male        10829.0    2018-12-05       No
# 999              Executive  Female        19252.0    2018-12-05      Yes
#
#         BusinessTravel  ... JobSatisfaction  WorkLifeBalance  \
# 0    Travel_Frequently  ...          Medium              Bad
# 1    Travel_Frequently  ...       Very High             Poor
# 2    Travel_Frequently  ...            High             Good
# 4    Travel_Frequently  ...             Low        Excellent
# 5    Travel_Frequently  ...             Low             Poor
# ..                 ...  ...             ...              ...
# 994  Travel_Frequently  ...             Low        Excellent
# 995  Travel_Frequently  ...            High        Excellent
# 996      Travel_Rarely  ...             Low        Excellent
# 998  Travel_Frequently  ...            High             Poor
# 999  Travel_Frequently  ...            High              Bad
#
#      EnvironmentSatisfaction YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                       Good                     5.0                   4.0
# 1                       Good                     5.0                   5.0
# 2                       Poor                     5.0                   4.0
# 4                  Excellent                     5.0                   5.0
# 5                        Bad                     8.0                   5.0
# ..                       ...                     ...                   ...
# 994                      Bad                     4.0                   5.0
# 995                     Poor                     0.0                   5.0
# 996                Excellent                     5.0                   5.0
# 998                      Bad                     5.0                   0.0
# 999                      Bad                     8.0                  14.0
#
#     JobInvolvement Attrition StockOptionLevel  PercentSalaryHike  \
# 0           Strong       Yes              0.0               19.0
# 1        Extremely       Yes              2.0               20.0
# 2        Extremely       Yes              0.0               20.0
# 4        Extremely       Yes              0.0               15.0
# 5          Minimal       Yes              0.0               24.0
# ..             ...       ...              ...                ...
# 994      Extremely       Yes              2.0               20.0
# 995        Minimal       Yes              2.0               23.0
# 996      Extremely        No              0.0               21.0
# 998        Minimal       Yes              3.0               11.0
# 999        Minimal       Yes              3.0               11.0
#
#      TotalWorkingYears
# 0                 20.0
# 1                  5.0
# 2                 13.0
# 4                 20.0
# 5                  1.0
# ..                 ...
# 994               20.0
# 995               20.0
# 996               20.0
# 998               20.0
# 999               20.0
#
# [965 rows x 25 columns]
